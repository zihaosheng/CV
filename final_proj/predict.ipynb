# %%
# !pip install opencv-python==4.2.0.32
# Out:
# Collecting opencv-python==4.2.0.32
#   Downloading https://files.pythonhosted.org/packages/68/c5/09a1b82f940805c2cee30c3c42786651edcfd0710a0283eb09c6bc959340/opencv_python-4.2.0.32-cp36-cp36m-manylinux1_x86_64.whl (28.2MB)
#      |████████████████████████████████| 28.2MB 109kB/s
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python==4.2.0.32) (1.18.5)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: opencv-python
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# Successfully installed opencv-python-4.2.0.32

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
import math
from collections import OrderedDict

#-------------------------------------------------#
#   MISH激活函数
#-------------------------------------------------#
class Mish(nn.Module):
    def __init__(self):
        super(Mish, self).__init__()

    def forward(self, x):
        return x * torch.tanh(F.softplus(x))

#-------------------------------------------------#
#   卷积块
#   CONV+BATCHNORM+MISH
#-------------------------------------------------#
class BasicConv(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1):
        super(BasicConv, self).__init__()

        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, stride, kernel_size//2, bias=False)
        self.bn = nn.BatchNorm2d(out_channels)
        self.activation = Mish()

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.activation(x)
        return x

#---------------------------------------------------#
#   CSPdarknet的结构块的组成部分
#   内部堆叠的残差块
#---------------------------------------------------#
class Resblock(nn.Module):
    def __init__(self, channels, hidden_channels=None, residual_activation=nn.Identity()):
        super(Resblock, self).__init__()

        if hidden_channels is None:
            hidden_channels = channels

        self.block = nn.Sequential(
            BasicConv(channels, hidden_channels, 1),
            BasicConv(hidden_channels, channels, 3)
        )

    def forward(self, x):
        return x + self.block(x)

#---------------------------------------------------#
#   CSPdarknet的结构块
#   存在一个大残差边
#   这个大残差边绕过了很多的残差结构
#---------------------------------------------------#
class Resblock_body(nn.Module):
    def __init__(self, in_channels, out_channels, num_blocks, first):
        super(Resblock_body, self).__init__()

        self.downsample_conv = BasicConv(in_channels, out_channels, 3, stride=2)

        if first:
            self.split_conv0 = BasicConv(out_channels, out_channels, 1)
            self.split_conv1 = BasicConv(out_channels, out_channels, 1)  
            self.blocks_conv = nn.Sequential(
                Resblock(channels=out_channels, hidden_channels=out_channels//2),
                BasicConv(out_channels, out_channels, 1)
            )
            self.concat_conv = BasicConv(out_channels*2, out_channels, 1)
        else:
            self.split_conv0 = BasicConv(out_channels, out_channels//2, 1)
            self.split_conv1 = BasicConv(out_channels, out_channels//2, 1)

            self.blocks_conv = nn.Sequential(
                *[Resblock(out_channels//2) for _ in range(num_blocks)],
                BasicConv(out_channels//2, out_channels//2, 1)
            )
            self.concat_conv = BasicConv(out_channels, out_channels, 1)

    def forward(self, x):
        x = self.downsample_conv(x)

        x0 = self.split_conv0(x)

        x1 = self.split_conv1(x)
        x1 = self.blocks_conv(x1)

        x = torch.cat([x1, x0], dim=1)
        x = self.concat_conv(x)

        return x

class CSPDarkNet(nn.Module):
    def __init__(self, layers):
        super(CSPDarkNet, self).__init__()
        self.inplanes = 32
        self.conv1 = BasicConv(3, self.inplanes, kernel_size=3, stride=1)
        self.feature_channels = [64, 128, 256, 512, 1024]

        self.stages = nn.ModuleList([
            Resblock_body(self.inplanes, self.feature_channels[0], layers[0], first=True),
            Resblock_body(self.feature_channels[0], self.feature_channels[1], layers[1], first=False),
            Resblock_body(self.feature_channels[1], self.feature_channels[2], layers[2], first=False),
            Resblock_body(self.feature_channels[2], self.feature_channels[3], layers[3], first=False),
            Resblock_body(self.feature_channels[3], self.feature_channels[4], layers[4], first=False)
        ])

        self.num_features = 1
        # 进行权值初始化
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()


    def forward(self, x):
        x = self.conv1(x)

        x = self.stages[0](x)
        x = self.stages[1](x)
        out3 = self.stages[2](x)
        out4 = self.stages[3](out3)
        out5 = self.stages[4](out4)

        return out3, out4, out5

def darknet53(pretrained, **kwargs):
    model = CSPDarkNet([1, 2, 8, 8, 4])
    if pretrained:
        if isinstance(pretrained, str):
            model.load_state_dict(torch.load(pretrained))
        else:
            raise Exception("darknet request a pretrained path. got [{}]".format(pretrained))
    return model

# %%
import torch
import torch.nn as nn
from collections import OrderedDict
# from nets.CSPdarknet import darknet53

def conv2d(filter_in, filter_out, kernel_size, stride=1):
    pad = (kernel_size - 1) // 2 if kernel_size else 0
    return nn.Sequential(OrderedDict([
        ("conv", nn.Conv2d(filter_in, filter_out, kernel_size=kernel_size, stride=stride, padding=pad, bias=False)),
        ("bn", nn.BatchNorm2d(filter_out)),
        ("relu", nn.LeakyReLU(0.1)),
    ]))

#---------------------------------------------------#
#   SPP结构，利用不同大小的池化核进行池化
#   池化后堆叠
#---------------------------------------------------#
class SpatialPyramidPooling(nn.Module):
    def __init__(self, pool_sizes=[5, 9, 13]):
        super(SpatialPyramidPooling, self).__init__()

        self.maxpools = nn.ModuleList([nn.MaxPool2d(pool_size, 1, pool_size//2) for pool_size in pool_sizes])

    def forward(self, x):
        features = [maxpool(x) for maxpool in self.maxpools[::-1]]
        features = torch.cat(features + [x], dim=1)

        return features

#---------------------------------------------------#
#   卷积 + 上采样
#---------------------------------------------------#
class Upsample(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Upsample, self).__init__()

        self.upsample = nn.Sequential(
            conv2d(in_channels, out_channels, 1),
            nn.Upsample(scale_factor=2, mode='nearest')
        )

    def forward(self, x,):
        x = self.upsample(x)
        return x

#---------------------------------------------------#
#   三次卷积块
#---------------------------------------------------#
def make_three_conv(filters_list, in_filters):
    m = nn.Sequential(
        conv2d(in_filters, filters_list[0], 1),
        conv2d(filters_list[0], filters_list[1], 3),
        conv2d(filters_list[1], filters_list[0], 1),
    )
    return m

#---------------------------------------------------#
#   五次卷积块
#---------------------------------------------------#
def make_five_conv(filters_list, in_filters):
    m = nn.Sequential(
        conv2d(in_filters, filters_list[0], 1),
        conv2d(filters_list[0], filters_list[1], 3),
        conv2d(filters_list[1], filters_list[0], 1),
        conv2d(filters_list[0], filters_list[1], 3),
        conv2d(filters_list[1], filters_list[0], 1),
    )
    return m

#---------------------------------------------------#
#   最后获得yolov4的输出
#---------------------------------------------------#
def yolo_head(filters_list, in_filters):
    m = nn.Sequential(
        conv2d(in_filters, filters_list[0], 3),
        nn.Conv2d(filters_list[0], filters_list[1], 1),
    )
    return m

#---------------------------------------------------#
#   yolo_body
#---------------------------------------------------#
class YoloBody(nn.Module):
    def __init__(self, num_anchors, num_classes):
        super(YoloBody, self).__init__()
        #  backbone
        self.backbone = darknet53(None)

        self.conv1 = make_three_conv([512,1024],1024)
        self.SPP = SpatialPyramidPooling()
        self.conv2 = make_three_conv([512,1024],2048)

        self.upsample1 = Upsample(512,256)
        self.conv_for_P4 = conv2d(512,256,1)
        self.make_five_conv1 = make_five_conv([256, 512],512)

        self.upsample2 = Upsample(256,128)
        self.conv_for_P3 = conv2d(256,128,1)
        self.make_five_conv2 = make_five_conv([128, 256],256)
        # 3*(5+num_classes)=3*(5+20)=3*(4+1+20)=75
        # 4+1+num_classes
        final_out_filter2 = num_anchors * (5 + num_classes)
        self.yolo_head3 = yolo_head([256, final_out_filter2],128)

        self.down_sample1 = conv2d(128,256,3,stride=2)
        self.make_five_conv3 = make_five_conv([256, 512],512)
        # 3*(5+num_classes)=3*(5+20)=3*(4+1+20)=75
        final_out_filter1 =  num_anchors * (5 + num_classes)
        self.yolo_head2 = yolo_head([512, final_out_filter1],256)


        self.down_sample2 = conv2d(256,512,3,stride=2)
        self.make_five_conv4 = make_five_conv([512, 1024],1024)
        # 3*(5+num_classes)=3*(5+20)=3*(4+1+20)=75
        final_out_filter0 =  num_anchors * (5 + num_classes)
        self.yolo_head1 = yolo_head([1024, final_out_filter0],512)


    def forward(self, x):
        #  backbone
        x2, x1, x0 = self.backbone(x)

        P5 = self.conv1(x0)
        P5 = self.SPP(P5)
        P5 = self.conv2(P5)

        P5_upsample = self.upsample1(P5)
        P4 = self.conv_for_P4(x1)
        P4 = torch.cat([P4,P5_upsample],axis=1)
        P4 = self.make_five_conv1(P4)

        P4_upsample = self.upsample2(P4)
        P3 = self.conv_for_P3(x2)
        P3 = torch.cat([P3,P4_upsample],axis=1)
        P3 = self.make_five_conv2(P3)

        P3_downsample = self.down_sample1(P3)
        P4 = torch.cat([P3_downsample,P4],axis=1)
        P4 = self.make_five_conv3(P4)

        P4_downsample = self.down_sample2(P4)
        P5 = torch.cat([P4_downsample,P5],axis=1)
        P5 = self.make_five_conv4(P5)

        out2 = self.yolo_head3(P3)
        out1 = self.yolo_head2(P4)
        out0 = self.yolo_head1(P5)

        return out0, out1, out2

# %%
from __future__ import division
import os
import math
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt

class DecodeBox(nn.Module):
    def __init__(self, anchors, num_classes, img_size):
        super(DecodeBox, self).__init__()
        self.anchors = anchors
        self.num_anchors = len(anchors)
        self.num_classes = num_classes
        self.bbox_attrs = 5 + num_classes
        self.img_size = img_size

    def forward(self, input):
        # input为bs,3*(1+4+num_classes),13,13

        # 一共多少张图片
        batch_size = input.size(0)
        # 13，13
        input_height = input.size(2)
        input_width = input.size(3)

        # 计算步长
        # 每一个特征点对应原来的图片上多少个像素点
        # 如果特征层为13x13的话，一个特征点就对应原来的图片上的32个像素点
        # 416/13 = 32
        stride_h = self.img_size[1] / input_height
        stride_w = self.img_size[0] / input_width

        # 把先验框的尺寸调整成特征层大小的形式
        # 计算出先验框在特征层上对应的宽高
        scaled_anchors = [(anchor_width / stride_w, anchor_height / stride_h) for anchor_width, anchor_height in self.anchors]

        # bs,3*(5+num_classes),13,13 -> bs,3,13,13,(5+num_classes)
        prediction = input.view(batch_size, self.num_anchors,
                                self.bbox_attrs, input_height, input_width).permute(0, 1, 3, 4, 2).contiguous()

        # 先验框的中心位置的调整参数
        x = torch.sigmoid(prediction[..., 0])  
        y = torch.sigmoid(prediction[..., 1])
        # 先验框的宽高调整参数
        w = prediction[..., 2]  # Width
        h = prediction[..., 3]  # Height

        # 获得置信度，是否有物体
        conf = torch.sigmoid(prediction[..., 4])
        # 种类置信度
        pred_cls = torch.sigmoid(prediction[..., 5:])  # Cls pred.

        FloatTensor = torch.cuda.FloatTensor if x.is_cuda else torch.FloatTensor
        LongTensor = torch.cuda.LongTensor if x.is_cuda else torch.LongTensor

        # 生成网格，先验框中心，网格左上角 batch_size,3,13,13
        grid_x = torch.linspace(0, input_width - 1, input_width).repeat(input_width, 1).repeat(
            batch_size * self.num_anchors, 1, 1).view(x.shape).type(FloatTensor)
        grid_y = torch.linspace(0, input_height - 1, input_height).repeat(input_height, 1).t().repeat(
            batch_size * self.num_anchors, 1, 1).view(y.shape).type(FloatTensor)

        # 生成先验框的宽高
        anchor_w = FloatTensor(scaled_anchors).index_select(1, LongTensor([0]))
        anchor_h = FloatTensor(scaled_anchors).index_select(1, LongTensor([1]))
        anchor_w = anchor_w.repeat(batch_size, 1).repeat(1, 1, input_height * input_width).view(w.shape)
        anchor_h = anchor_h.repeat(batch_size, 1).repeat(1, 1, input_height * input_width).view(h.shape)
        
        # 计算调整后的先验框中心与宽高
        pred_boxes = FloatTensor(prediction[..., :4].shape)
        pred_boxes[..., 0] = x.data + grid_x
        pred_boxes[..., 1] = y.data + grid_y
        pred_boxes[..., 2] = torch.exp(w.data) * anchor_w
        pred_boxes[..., 3] = torch.exp(h.data) * anchor_h

        # fig = plt.figure()
        # ax = fig.add_subplot(121)
        # if input_height==13:
        #     plt.ylim(0,13)
        #     plt.xlim(0,13)
        # elif input_height==26:
        #     plt.ylim(0,26)
        #     plt.xlim(0,26)
        # elif input_height==52:
        #     plt.ylim(0,52)
        #     plt.xlim(0,52)
        # plt.scatter(grid_x.cpu(),grid_y.cpu())

        # anchor_left = grid_x - anchor_w/2 
        # anchor_top = grid_y - anchor_h/2 

        # rect1 = plt.Rectangle([anchor_left[0,0,5,5],anchor_top[0,0,5,5]],anchor_w[0,0,5,5],anchor_h[0,0,5,5],color="r",fill=False)
        # rect2 = plt.Rectangle([anchor_left[0,1,5,5],anchor_top[0,1,5,5]],anchor_w[0,1,5,5],anchor_h[0,1,5,5],color="r",fill=False)
        # rect3 = plt.Rectangle([anchor_left[0,2,5,5],anchor_top[0,2,5,5]],anchor_w[0,2,5,5],anchor_h[0,2,5,5],color="r",fill=False)

        # ax.add_patch(rect1)
        # ax.add_patch(rect2)
        # ax.add_patch(rect3)

        # ax = fig.add_subplot(122)
        # if input_height==13:
        #     plt.ylim(0,13)
        #     plt.xlim(0,13)
        # elif input_height==26:
        #     plt.ylim(0,26)
        #     plt.xlim(0,26)
        # elif input_height==52:
        #     plt.ylim(0,52)
        #     plt.xlim(0,52)
        # plt.scatter(grid_x.cpu(),grid_y.cpu())
        # plt.scatter(pred_boxes[0,:,5,5,0].cpu(),pred_boxes[0,:,5,5,1].cpu(),c='r')

        # pre_left = pred_boxes[...,0] - pred_boxes[...,2]/2 
        # pre_top = pred_boxes[...,1] - pred_boxes[...,3]/2 

        # rect1 = plt.Rectangle([pre_left[0,0,5,5],pre_top[0,0,5,5]],pred_boxes[0,0,5,5,2],pred_boxes[0,0,5,5,3],color="r",fill=False)
        # rect2 = plt.Rectangle([pre_left[0,1,5,5],pre_top[0,1,5,5]],pred_boxes[0,1,5,5,2],pred_boxes[0,1,5,5,3],color="r",fill=False)
        # rect3 = plt.Rectangle([pre_left[0,2,5,5],pre_top[0,2,5,5]],pred_boxes[0,2,5,5,2],pred_boxes[0,2,5,5,3],color="r",fill=False)

        # ax.add_patch(rect1)
        # ax.add_patch(rect2)
        # ax.add_patch(rect3)

        # plt.show()
        # 用于将输出调整为相对于416x416的大小
        _scale = torch.Tensor([stride_w, stride_h] * 2).type(FloatTensor)
        output = torch.cat((pred_boxes.view(batch_size, -1, 4) * _scale,
                            conf.view(batch_size, -1, 1), pred_cls.view(batch_size, -1, self.num_classes)), -1)
        return output.data
        
def letterbox_image(image, size):
    iw, ih = image.size
    w, h = size
    scale = min(w/iw, h/ih)
    nw = int(iw*scale)
    nh = int(ih*scale)

    image = image.resize((nw,nh), Image.BICUBIC)
    new_image = Image.new('RGB', size, (128,128,128))
    new_image.paste(image, ((w-nw)//2, (h-nh)//2))
    return new_image

def yolo_correct_boxes(top, left, bottom, right, input_shape, image_shape):
    new_shape = image_shape*np.min(input_shape/image_shape)

    offset = (input_shape-new_shape)/2./input_shape
    scale = input_shape/new_shape

    box_yx = np.concatenate(((top+bottom)/2,(left+right)/2),axis=-1)/input_shape
    box_hw = np.concatenate((bottom-top,right-left),axis=-1)/input_shape

    box_yx = (box_yx - offset) * scale
    box_hw *= scale

    box_mins = box_yx - (box_hw / 2.)
    box_maxes = box_yx + (box_hw / 2.)
    boxes =  np.concatenate([
        box_mins[:, 0:1],
        box_mins[:, 1:2],
        box_maxes[:, 0:1],
        box_maxes[:, 1:2]
    ],axis=-1)
    print(np.shape(boxes))
    boxes *= np.concatenate([image_shape, image_shape],axis=-1)
    return boxes

def bbox_iou(box1, box2, x1y1x2y2=True):
    """
        计算IOU
    """
    if not x1y1x2y2:
        b1_x1, b1_x2 = box1[:, 0] - box1[:, 2] / 2, box1[:, 0] + box1[:, 2] / 2
        b1_y1, b1_y2 = box1[:, 1] - box1[:, 3] / 2, box1[:, 1] + box1[:, 3] / 2
        b2_x1, b2_x2 = box2[:, 0] - box2[:, 2] / 2, box2[:, 0] + box2[:, 2] / 2
        b2_y1, b2_y2 = box2[:, 1] - box2[:, 3] / 2, box2[:, 1] + box2[:, 3] / 2
    else:
        b1_x1, b1_y1, b1_x2, b1_y2 = box1[:, 0], box1[:, 1], box1[:, 2], box1[:, 3]
        b2_x1, b2_y1, b2_x2, b2_y2 = box2[:, 0], box2[:, 1], box2[:, 2], box2[:, 3]

    inter_rect_x1 = torch.max(b1_x1, b2_x1)
    inter_rect_y1 = torch.max(b1_y1, b2_y1)
    inter_rect_x2 = torch.min(b1_x2, b2_x2)
    inter_rect_y2 = torch.min(b1_y2, b2_y2)

    inter_area = torch.clamp(inter_rect_x2 - inter_rect_x1 + 1, min=0) * \
                 torch.clamp(inter_rect_y2 - inter_rect_y1 + 1, min=0)
                 
    b1_area = (b1_x2 - b1_x1 + 1) * (b1_y2 - b1_y1 + 1)
    b2_area = (b2_x2 - b2_x1 + 1) * (b2_y2 - b2_y1 + 1)

    iou = inter_area / (b1_area + b2_area - inter_area + 1e-16)

    return iou


def non_max_suppression(prediction, num_classes, conf_thres=0.5, nms_thres=0.4):
    # 求左上角和右下角
    box_corner = prediction.new(prediction.shape)
    box_corner[:, :, 0] = prediction[:, :, 0] - prediction[:, :, 2] / 2
    box_corner[:, :, 1] = prediction[:, :, 1] - prediction[:, :, 3] / 2
    box_corner[:, :, 2] = prediction[:, :, 0] + prediction[:, :, 2] / 2
    box_corner[:, :, 3] = prediction[:, :, 1] + prediction[:, :, 3] / 2
    prediction[:, :, :4] = box_corner[:, :, :4]

    output = [None for _ in range(len(prediction))]
    for image_i, image_pred in enumerate(prediction):
        # 利用置信度进行第一轮筛选
        conf_mask = (image_pred[:, 4] >= conf_thres).squeeze()
        image_pred = image_pred[conf_mask]

        if not image_pred.size(0):
            continue

        # 获得种类及其置信度
        class_conf, class_pred = torch.max(image_pred[:, 5:5 + num_classes], 1, keepdim=True)

        # 获得的内容为(x1, y1, x2, y2, obj_conf, class_conf, class_pred)
        detections = torch.cat((image_pred[:, :5], class_conf.float(), class_pred.float()), 1)

        # 获得种类
        unique_labels = detections[:, -1].cpu().unique()

        if prediction.is_cuda:
            unique_labels = unique_labels.cuda()

        for c in unique_labels:
            # 获得某一类初步筛选后全部的预测结果
            detections_class = detections[detections[:, -1] == c]
            # 按照存在物体的置信度排序
            _, conf_sort_index = torch.sort(detections_class[:, 4], descending=True)
            detections_class = detections_class[conf_sort_index]
            # 进行非极大抑制
            max_detections = []
            while detections_class.size(0):
                # 取出这一类置信度最高的，一步一步往下判断，判断重合程度是否大于nms_thres，如果是则去除掉
                max_detections.append(detections_class[0].unsqueeze(0))
                if len(detections_class) == 1:
                    break
                ious = bbox_iou(max_detections[-1], detections_class[1:])
                detections_class = detections_class[1:][ious < nms_thres]
            # 堆叠
            max_detections = torch.cat(max_detections).data
            # Add max detections to outputs
            output[image_i] = max_detections if output[image_i] is None else torch.cat(
                (output[image_i], max_detections))

    return output

def merge_bboxes(bboxes, cutx, cuty):
    merge_bbox = []
    for i in range(len(bboxes)):
        for box in bboxes[i]:
            tmp_box = []
            x1,y1,x2,y2 = box[0], box[1], box[2], box[3]

            if i == 0:
                if y1 > cuty or x1 > cutx:
                    continue
                if y2 >= cuty and y1 <= cuty:
                    y2 = cuty
                    if y2-y1 < 5:
                        continue
                if x2 >= cutx and x1 <= cutx:
                    x2 = cutx
                    if x2-x1 < 5:
                        continue
                
            if i == 1:
                if y2 < cuty or x1 > cutx:
                    continue

                if y2 >= cuty and y1 <= cuty:
                    y1 = cuty
                    if y2-y1 < 5:
                        continue
                
                if x2 >= cutx and x1 <= cutx:
                    x2 = cutx
                    if x2-x1 < 5:
                        continue

            if i == 2:
                if y2 < cuty or x2 < cutx:
                    continue

                if y2 >= cuty and y1 <= cuty:
                    y1 = cuty
                    if y2-y1 < 5:
                        continue

                if x2 >= cutx and x1 <= cutx:
                    x1 = cutx
                    if x2-x1 < 5:
                        continue

            if i == 3:
                if y1 > cuty or x2 < cutx:
                    continue

                if y2 >= cuty and y1 <= cuty:
                    y2 = cuty
                    if y2-y1 < 5:
                        continue

                if x2 >= cutx and x1 <= cutx:
                    x1 = cutx
                    if x2-x1 < 5:
                        continue

            tmp_box.append(x1)
            tmp_box.append(y1)
            tmp_box.append(x2)
            tmp_box.append(y2)
            tmp_box.append(box[-1])
            merge_bbox.append(tmp_box)
    return merge_bbox

# %%
#-------------------------------------#
#       创建YOLO类
#-------------------------------------#
import cv2
import numpy as np
import colorsys
import os
import torch
import torch.nn as nn
# from nets.yolo4 import YoloBody
import torch.backends.cudnn as cudnn
from PIL import Image, ImageFont, ImageDraw
from torch.autograd import Variable
# from utils.utils import non_max_suppression, bbox_iou, DecodeBox, letterbox_image, yolo_correct_boxes

class YOLO(object):
    _defaults = {
        "model_path": '/content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth',
        "anchors_path": '/content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolo_anchors.txt',
        "classes_path": '/content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/mask_classes.txt',
        "model_image_size" : (608, 608, 3),
        "confidence": 0.5,
        "cuda": True
    }

    @classmethod
    def get_defaults(cls, n):
        if n in cls._defaults:
            return cls._defaults[n]
        else:
            return "Unrecognized attribute name '" + n + "'"

    #---------------------------------------------------#
    #   初始化YOLO
    #---------------------------------------------------#
    def __init__(self, **kwargs):
        self.__dict__.update(self._defaults)
        self.class_names = self._get_class()
        self.anchors = self._get_anchors()
        self.generate()
    #---------------------------------------------------#
    #   获得所有的分类
    #---------------------------------------------------#
    def _get_class(self):
        classes_path = os.path.expanduser(self.classes_path)
        with open(classes_path) as f:
            class_names = f.readlines()
        class_names = [c.strip() for c in class_names]
        return class_names
    
    #---------------------------------------------------#
    #   获得所有的先验框
    #---------------------------------------------------#
    def _get_anchors(self):
        anchors_path = os.path.expanduser(self.anchors_path)
        with open(anchors_path) as f:
            anchors = f.readline()
        anchors = [float(x) for x in anchors.split(',')]
        return np.array(anchors).reshape([-1, 3, 2])[::-1,:,:]

    #---------------------------------------------------#
    #   获得所有的分类
    #---------------------------------------------------#
    def generate(self):
        
        self.net = YoloBody(len(self.anchors[0]), len(self.class_names)).eval()

        # 加快模型训练的效率
        print('Loading pretrained weights.')
        
        model_dict = self.net.state_dict()
        pretrained_dict = torch.load(self.model_path)
        pretrained_dict = {k: v for k, v in pretrained_dict.items() if np.shape(model_dict[k]) ==  np.shape(v)}
        model_dict.update(pretrained_dict)
        self.net.load_state_dict(model_dict)
        
        if self.cuda:
            os.environ["CUDA_VISIBLE_DEVICES"] = '0'
            self.net = nn.DataParallel(self.net)
            self.net = self.net.cuda()
    
        print('Finish loading!')

        self.yolo_decodes = []
        for i in range(3):
            self.yolo_decodes.append(DecodeBox(self.anchors[i], len(self.class_names),  (self.model_image_size[1], self.model_image_size[0])))


        print('{} model, anchors, and classes loaded.'.format(self.model_path))
        # 画框设置不同的颜色
        hsv_tuples = [(x / len(self.class_names), 1., 1.)
                      for x in range(len(self.class_names))]
        self.colors = list(map(lambda x: colorsys.hsv_to_rgb(*x), hsv_tuples))
        self.colors = list(
            map(lambda x: (int(x[0] * 255), int(x[1] * 255), int(x[2] * 255)),
                self.colors))

    #---------------------------------------------------#
    #   检测图片
    #---------------------------------------------------#
    def detect_image(self, image):
        image_shape = np.array(np.shape(image)[0:2])

        crop_img = np.array(letterbox_image(image, (self.model_image_size[0],self.model_image_size[1])))
        photo = np.array(crop_img,dtype = np.float32)
        photo /= 255.0
        photo = np.transpose(photo, (2, 0, 1))
        photo = photo.astype(np.float32)
        images = []
        images.append(photo)
        images = np.asarray(images)

        with torch.no_grad():
            images = torch.from_numpy(images)
            if self.cuda:
                images = images.cuda()
            outputs = self.net(images)
            
        output_list = []
        for i in range(3):
            output_list.append(self.yolo_decodes[i](outputs[i]))
        output = torch.cat(output_list, 1)
        batch_detections = non_max_suppression(output, len(self.class_names),
                                                conf_thres=self.confidence,
                                                nms_thres=0.3)
        try:
            batch_detections = batch_detections[0].cpu().numpy()
        except:
            return image
            
        top_index = batch_detections[:,4]*batch_detections[:,5] > self.confidence
        top_conf = batch_detections[top_index,4]*batch_detections[top_index,5]
        top_label = np.array(batch_detections[top_index,-1],np.int32)
        top_bboxes = np.array(batch_detections[top_index,:4])
        top_xmin, top_ymin, top_xmax, top_ymax = np.expand_dims(top_bboxes[:,0],-1),np.expand_dims(top_bboxes[:,1],-1),np.expand_dims(top_bboxes[:,2],-1),np.expand_dims(top_bboxes[:,3],-1)

        # 去掉灰条
        boxes = yolo_correct_boxes(top_ymin,top_xmin,top_ymax,top_xmax,np.array([self.model_image_size[0],self.model_image_size[1]]),image_shape)

        font = ImageFont.truetype(font='/content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/simhei.ttf',size=np.floor(3e-2 * np.shape(image)[1] + 0.5).astype('int32'))

        thickness = (np.shape(image)[0] + np.shape(image)[1]) // self.model_image_size[0]

        for i, c in enumerate(top_label):
            predicted_class = self.class_names[c]
            score = top_conf[i]

            top, left, bottom, right = boxes[i]
            top = top - 5
            left = left - 5
            bottom = bottom + 5
            right = right + 5

            top = max(0, np.floor(top + 0.5).astype('int32'))
            left = max(0, np.floor(left + 0.5).astype('int32'))
            bottom = min(np.shape(image)[0], np.floor(bottom + 0.5).astype('int32'))
            right = min(np.shape(image)[1], np.floor(right + 0.5).astype('int32'))

            # 画框框
            label = '{}: {:.2f}'.format(predicted_class, score)
            draw = ImageDraw.Draw(image)
            label_size = draw.textsize(label, font)
            label = label.encode('utf-8')
            print(label)
            
            if top - label_size[1] >= 0:
                text_origin = np.array([left, top - label_size[1]])
            else:
                text_origin = np.array([left, top + 1])

            for i in range(thickness):
                draw.rectangle(
                    [left + i, top + i, right - i, bottom - i],
                    outline=self.colors[self.class_names.index(predicted_class)])
            draw.rectangle(
                [tuple(text_origin), tuple(text_origin + label_size)],
                fill=self.colors[self.class_names.index(predicted_class)])
            draw.text(text_origin, str(label,'UTF-8'), fill=(0, 0, 0), font=font)
            del draw
        return image

# %%
import cv2
import time
import numpy as np
# from yolo import YOLO
from PIL import Image

# %%
#-------------------------------------#
#       对单张图片进行预测
#-------------------------------------#
def detect_image(image_path):
    print('Start detect!')
    yolo = YOLO()
    try:
        image = Image.open(image_path)
    except:
        print('Open Error! Try again!')
        pass
    else:
        r_image = yolo.detect_image(image)
        image_path = image_path.replace('black_mask','result')
        print(image_path.split('.')[0] + '_result.png')
        r_image.save(image_path.split('.')[0] + '_result.png')
    print('Finish detect!')

# %%
#-------------------------------------#
#       对一段视频进行检测
#-------------------------------------#
def detect_video(video_path):
    print('Start detect!')
    yolo = YOLO()
    capture = cv2.VideoCapture(video_path)
    writer = None
    fps = 0.0
    while True:
        t1 = time.time()
        
        # 读取某一帧
        grabbed, frame = capture.read()
        print('===========================>',grabbed)
        if not grabbed:
            break
        # opencv读取的是BGR，格式转变，BGRtoRGB
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        # 转变成Image
        frame = Image.fromarray(np.uint8(frame))
        # 进行检测
        frame = np.array(yolo.detect_image(frame))
        # RGBtoBGR满足opencv显示格式
        frame = cv2.cvtColor(frame,cv2.COLOR_RGB2BGR)

        fps  = (fps + (1. / (time.time() - t1))) / 2
        print("FPS: %.2f" % (fps))
        frame = cv2.putText(frame, "FPS: %.2f" % (fps), (0, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2, cv2.LINE_AA)
        
        if writer is None:
            print('writee')
            fourcc = cv2.VideoWriter_fourcc(*'MP4V')
            writer = cv2.VideoWriter(video_path.split('.')[0] + '_result.mp4', fourcc, 30, (frame.shape[1], frame.shape[0]), True)
        writer.write(frame)
    # if writer is not None:
    writer.release()
    capture.release()
    print('Finish detect!')

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

black_mask_paths = np.sort(os.listdir('/content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask'))
i = 0
for _ in black_mask_paths:
  i+=1
  print('===========>',i)
  print('/content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/'+_)
  detect_image('/content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/'+_)
# Out:
# ===========> 1
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_10.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.99'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_10_result.png
# Finish detect!
# ===========> 2
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_101.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.87'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_101_result.png
# Finish detect!
# ===========> 3
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_103.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.95'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_103_result.png
# Finish detect!
# ===========> 4
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_105.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.94'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_105_result.png
# Finish detect!
# ===========> 5
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_106.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.98'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_106_result.png
# Finish detect!
# ===========> 6
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_107.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.95'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_107_result.png
# Finish detect!
# ===========> 7
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_108.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.94'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_108_result.png
# Finish detect!
# ===========> 8
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_110.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.94'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_110_result.png
# Finish detect!
# ===========> 9
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_111.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.99'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_111_result.png
# Finish detect!
# ===========> 10
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_112.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.97'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_112_result.png
# Finish detect!
# ===========> 11
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_114.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.87'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_114_result.png
# Finish detect!
# ===========> 12
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_116.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'nomask: 0.76'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_116_result.png
# Finish detect!
# ===========> 13
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_117.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.98'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_117_result.png
# Finish detect!
# ===========> 14
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_118.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.95'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_118_result.png
# Finish detect!
# ===========> 15
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_119.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.94'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_119_result.png
# Finish detect!
# ===========> 16
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_12.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.95'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_12_result.png
# Finish detect!
# ===========> 17
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_121.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.99'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_121_result.png
# Finish detect!
# ===========> 18
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_122.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.97'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_122_result.png
# Finish detect!
# ===========> 19
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_127.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.97'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_127_result.png
# Finish detect!
# ===========> 20
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_128.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.80'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_128_result.png
# Finish detect!
# ===========> 21
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_130.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.87'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_130_result.png
# Finish detect!
# ===========> 22
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_131.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.98'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_131_result.png
# Finish detect!
# ===========> 23
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_133.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.59'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_133_result.png
# Finish detect!
# ===========> 24
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_135.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.93'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_135_result.png
# Finish detect!
# ===========> 25
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_136.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.94'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_136_result.png
# Finish detect!
# ===========> 26
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_137.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.98'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_137_result.png
# Finish detect!
# ===========> 27
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_141.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.98'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_141_result.png
# Finish detect!
# ===========> 28
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_142.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.88'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_142_result.png
# Finish detect!
# ===========> 29
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_143.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_143_result.png
# Finish detect!
# ===========> 30
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_144.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.91'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_144_result.png
# Finish detect!
# ===========> 31
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_147.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.89'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_147_result.png
# Finish detect!
# ===========> 32
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_149.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.99'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_149_result.png
# Finish detect!
# ===========> 33
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_15.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (2, 4)
# b'mask: 0.99'
# b'mask: 0.99'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_15_result.png
# Finish detect!
# ===========> 34
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_150.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.94'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_150_result.png
# Finish detect!
# ===========> 35
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_151.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (2, 4)
# b'mask: 0.97'
# b'mask: 0.93'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_151_result.png
# Finish detect!
# ===========> 36
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_153.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (0, 4)
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_153_result.png
# Finish detect!
# ===========> 37
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_154.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.97'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_154_result.png
# Finish detect!
# ===========> 38
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_155.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.97'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_155_result.png
# Finish detect!
# ===========> 39
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_156.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.97'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_156_result.png
# Finish detect!
# ===========> 40
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_157.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.98'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_157_result.png
# Finish detect!
# ===========> 41
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_158.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.97'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_158_result.png
# Finish detect!
# ===========> 42
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_159.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.91'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_159_result.png
# Finish detect!
# ===========> 43
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_16.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.95'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_16_result.png
# Finish detect!
# ===========> 44
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_162.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.98'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_162_result.png
# Finish detect!
# ===========> 45
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_166.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.97'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_166_result.png
# Finish detect!
# ===========> 46
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_167.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_167_result.png
# Finish detect!
# ===========> 47
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_168.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.88'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_168_result.png
# Finish detect!
# ===========> 48
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_169.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.93'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_169_result.png
# Finish detect!
# ===========> 49
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_17.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.96'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_17_result.png
# Finish detect!
# ===========> 50
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_171.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.98'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_171_result.png
# Finish detect!
# ===========> 51
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_177.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.98'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_177_result.png
# Finish detect!
# ===========> 52
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_178.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'nomask: 0.52'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_178_result.png
# Finish detect!
# ===========> 53
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_179.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_179_result.png
# Finish detect!
# ===========> 54
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_18.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.99'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_18_result.png
# Finish detect!
# ===========> 55
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_180.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.97'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_180_result.png
# Finish detect!
# ===========> 56
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_182.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.88'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_182_result.png
# Finish detect!
# ===========> 57
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_183.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.97'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_183_result.png
# Finish detect!
# ===========> 58
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_185.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.97'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_185_result.png
# Finish detect!
# ===========> 59
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_186.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (3, 4)
# b'mask: 0.97'
# b'mask: 0.90'
# b'mask: 0.89'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_186_result.png
# Finish detect!
# ===========> 60
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_188.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.98'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_188_result.png
# Finish detect!
# ===========> 61
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_189.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (5, 4)
# b'mask: 0.86'
# b'nomask: 0.95'
# b'nomask: 0.85'
# b'nomask: 0.54'
# b'nomask: 0.53'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_189_result.png
# Finish detect!
# ===========> 62
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_191.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_191_result.png
# Finish detect!
# ===========> 63
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_193.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_193_result.png
# Finish detect!
# ===========> 64
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_195.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.95'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_195_result.png
# Finish detect!
# ===========> 65
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_20.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.96'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_20_result.png
# Finish detect!
# ===========> 66
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_22.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.99'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_22_result.png
# Finish detect!
# ===========> 67
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_23.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.98'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_23_result.png
# Finish detect!
# ===========> 68
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_24.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.97'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_24_result.png
# Finish detect!
# ===========> 69
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_26.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.97'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_26_result.png
# Finish detect!
# ===========> 70
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_27.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.97'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_27_result.png
# Finish detect!
# ===========> 71
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_28.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.98'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_28_result.png
# Finish detect!
# ===========> 72
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_31.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (2, 4)
# b'mask: 0.99'
# b'mask: 0.98'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_31_result.png
# Finish detect!
# ===========> 73
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_33.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.99'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_33_result.png
# Finish detect!
# ===========> 74
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_35.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.85'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_35_result.png
# Finish detect!
# ===========> 75
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_36.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.95'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_36_result.png
# Finish detect!
# ===========> 76
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_37.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.99'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_37_result.png
# Finish detect!
# ===========> 77
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_38.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (2, 4)
# b'mask: 0.99'
# b'mask: 0.99'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_38_result.png
# Finish detect!
# ===========> 78
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_39.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.96'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_39_result.png
# Finish detect!
# ===========> 79
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_4.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.95'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_4_result.png
# Finish detect!
# ===========> 80
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_40.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.98'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_40_result.png
# Finish detect!
# ===========> 81
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_43.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.99'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_43_result.png
# Finish detect!
# ===========> 82
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_44.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.99'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_44_result.png
# Finish detect!
# ===========> 83
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_45.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.97'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_45_result.png
# Finish detect!
# ===========> 84
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_46.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.97'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_46_result.png
# Finish detect!
# ===========> 85
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_47.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_47_result.png
# Finish detect!
# ===========> 86
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_48.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.98'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_48_result.png
# Finish detect!
# ===========> 87
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_49.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_49_result.png
# Finish detect!
# ===========> 88
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_5.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.99'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_5_result.png
# Finish detect!
# ===========> 89
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_50.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.64'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_50_result.png
# Finish detect!
# ===========> 90
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_51.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.94'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_51_result.png
# Finish detect!
# ===========> 91
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_53.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.96'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_53_result.png
# Finish detect!
# ===========> 92
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_54.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.98'
# /content/gdrive/My Drive/cv_final/yolo_pytorch/result/result_54_result.png
# Finish detect!
# ===========> 93
# /content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/black_mask_56.jpg
# Start detect!
# Loading pretrained weights.
# Finish loading!
# /content/gdrive/My Drive/cv_final/yolo_pytorch/model_data/yolov4_maskdetect_weights2.pth model, anchors, and classes loaded.
# (1, 4)
# b'mask: 0.98'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-1a5b92bc077c> in <module>()
#       7   print('===========>',i)
#       8   print('/content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/'+_)
# ----> 9   detect_image('/content/gdrive/My Drive/cv_final/yolo_pytorch/black_mask/'+_)
#
# <ipython-input-13-3d0fc255bce6> in detect_image(image_path)
#      11         pass
#      12     else:
# ---> 13         r_image = yolo.detect_image(image)
#      14         image_path = image_path.replace('black_mask','result')
#      15         print(image_path.split('.')[0] + '_result.png')
#
# <ipython-input-11-ef4f5d9302dd> in detect_image(self, image)
#     172                 draw.rectangle(
#     173                     [left + i, top + i, right - i, bottom - i],
# --> 174                     outline=self.colors[self.class_names.index(predicted_class)])
#     175             draw.rectangle(
#     176                 [tuple(text_origin), tuple(text_origin + label_size)],
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageDraw.py in rectangle(self, xy, fill, outline, width)
#     244     def rectangle(self, xy, fill=None, outline=None, width=0):
#     245         """Draw a rectangle."""
# --> 246         ink, fill = self._getink(outline, fill)
#     247         if fill is not None:
#     248             self.draw.draw_rectangle(xy, fill, 1)
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageDraw.py in _getink(self, ink, fill)
#     111                 if self.palette and not isinstance(ink, numbers.Number):
#     112                     ink = self.palette.getcolor(ink)
# --> 113                 ink = self.draw.draw_ink(ink)
#     114             if fill is not None:
#     115                 if isinstance(fill, str):
#
# TypeError: function takes exactly 1 argument (3 given)

# %%
detect_video('/content/gdrive/My Drive/cv_final/yolo_pytorch/test_black.mp4')
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# b'nomask: 0.81'
# FPS: 13.09
# ===========================> True
# (4, 4)
# b'mask: 0.95'
# b'nomask: 0.97'
# b'nomask: 0.92'
# b'nomask: 0.81'
# FPS: 13.10
# ===========================> True
# (4, 4)
# b'mask: 0.95'
# b'nomask: 0.97'
# b'nomask: 0.92'
# b'nomask: 0.81'
# FPS: 13.00
# ===========================> True
# (4, 4)
# b'mask: 0.95'
# b'nomask: 0.97'
# b'nomask: 0.92'
# b'nomask: 0.81'
# FPS: 12.90
# ===========================> True
# (4, 4)
# b'mask: 0.95'
# b'nomask: 0.97'
# b'nomask: 0.92'
# b'nomask: 0.81'
# FPS: 12.85
# ===========================> True
# (4, 4)
# b'mask: 0.95'
# b'nomask: 0.97'
# b'nomask: 0.92'
# b'nomask: 0.81'
# FPS: 12.92
# ===========================> True
# (4, 4)
# b'mask: 0.95'
# b'mask: 0.65'
# b'nomask: 0.70'
# b'nomask: 0.61'
# FPS: 13.04
# ===========================> True
# (4, 4)
# b'mask: 0.95'
# b'mask: 0.66'
# b'nomask: 0.71'
# b'nomask: 0.58'
# FPS: 12.94
# ===========================> True
# (4, 4)
# b'mask: 0.95'
# b'mask: 0.65'
# b'nomask: 0.67'
# b'nomask: 0.61'
# FPS: 13.01
# ===========================> True
# (4, 4)
# b'mask: 0.95'
# b'mask: 0.65'
# b'nomask: 0.69'
# b'nomask: 0.61'
# FPS: 12.69
# ===========================> True
# (4, 4)
# b'mask: 0.95'
# b'mask: 0.65'
# b'nomask: 0.67'
# b'nomask: 0.61'
# FPS: 12.88
# ===========================> True
# (4, 4)
# b'mask: 0.95'
# b'mask: 0.65'
# b'nomask: 0.68'
# b'nomask: 0.95'
# FPS: 13.57
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.60
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.72
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.81
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.76
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.76
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.79
# ===========================> True
# (1, 4)
# b'nomask: 0.94'
# FPS: 13.91
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.84
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.77
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.76
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.77
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.79
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.77
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.75
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.88
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.81
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.85
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.79
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.45
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.24
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.29
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.51
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.67
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.61
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.63
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.69
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.69
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.71
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.74
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.68
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.53
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.68
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.62
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.55
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.53
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.62
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.43
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.41
# ===========================> True
# (1, 4)
# b'nomask: 0.88'
# FPS: 13.53
# ===========================> True
# (1, 4)
# b'nomask: 0.89'
# FPS: 13.52
# ===========================> True
# (1, 4)
# b'nomask: 0.92'
# FPS: 13.75
# ===========================> True
# (1, 4)
# b'nomask: 0.93'
# FPS: 13.74
# ===========================> True
# (1, 4)
# b'nomask: 0.94'
# FPS: 13.76
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.82
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.72
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.72
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.85
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.72
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.70
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.47
# ===========================> True
# (1, 4)
# b'nomask: 0.95'
# FPS: 13.70
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.70
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.80
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.62
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.64
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.81
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.90
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.90
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.86
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.46
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.47
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.66
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.71
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.59
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.85
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.76
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.83
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.42
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.75
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.82
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.88
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.38
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.36
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.50
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.81
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.84
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.82
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.87
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.69
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.77
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.71
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.52
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.44
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.63
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.75
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.76
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.91
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.88
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.77
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.57
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.56
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.46
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.38
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.56
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.49
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.45
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.59
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.64
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.45
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.27
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.30
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.32
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.23
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 12.86
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.03
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.06
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.08
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.29
# ===========================> True
# (1, 4)
# b'nomask: 0.96'
# FPS: 13.45
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.54
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.70
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.81
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.80
# ===========================> True
# (1, 4)
# b'nomask: 0.97'
# FPS: 13.80
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.65
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.58
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.57
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.58
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.57
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.51
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.55
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.63
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.55
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.64
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.66
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.35
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 12.93
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 12.90
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.08
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.28
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.57
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.58
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.72
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.67
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.63
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.83
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.90
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.71
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.82
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.72
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.60
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.73
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.84
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.84
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.91
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.70
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.68
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.76
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.80
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.77
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.86
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.76
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.94
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.78
# ===========================> True
# (1, 4)
# b'nomask: 0.98'
# FPS: 13.77
# ===========================> True
# (1, 4)
# b'nomask: 0.74'
# b'nomask: 0.67'
# FPS: 13.60
# ===========================> True
# (2, 4)
# b'nomask: 0.76'
# b'nomask: 0.71'
# FPS: 13.69
# ===========================> True
# (2, 4)
# b'nomask: 0.71'
# b'nomask: 0.64'
# FPS: 13.70
# ===========================> True
# (2, 4)
# b'nomask: 0.65'
# b'nomask: 0.62'
# FPS: 13.66
# ===========================> True
# (2, 4)
# b'nomask: 0.69'
# b'nomask: 0.67'
# FPS: 13.46
# ===========================> True
# (2, 4)
# b'nomask: 0.73'
# b'nomask: 0.67'
# FPS: 13.24
# ===========================> True
# (2, 4)
# b'nomask: 0.76'
# b'nomask: 0.69'
# FPS: 13.38
# ===========================> True
# (2, 4)
# b'nomask: 0.83'
# b'nomask: 0.69'
# FPS: 13.44
# ===========================> True
# (2, 4)
# b'nomask: 0.79'
# b'nomask: 0.69'
# FPS: 13.49
# ===========================> True
# (2, 4)
# b'nomask: 0.76'
# b'nomask: 0.69'
# FPS: 13.59
# ===========================> True
# (2, 4)
# b'nomask: 0.74'
# b'nomask: 0.68'
# FPS: 13.48
# ===========================> True
# (3, 4)
# b'nomask: 0.73'
# b'nomask: 0.68'
# b'nomask: 0.62'
# FPS: 13.25
# ===========================> True
# (3, 4)
# b'nomask: 0.73'
# b'nomask: 0.68'
# b'nomask: 0.64'
# FPS: 13.18
# ===========================> True
# (3, 4)
# b'nomask: 0.78'
# b'nomask: 0.66'
# b'nomask: 0.61'
# FPS: 13.20
# ===========================> True
# (3, 4)
# b'nomask: 0.80'
# b'nomask: 0.68'
# b'nomask: 0.61'
# FPS: 13.25
# ===========================> True
# (3, 4)
# b'nomask: 0.79'
# b'nomask: 0.67'
# b'nomask: 0.63'
# FPS: 13.17
# ===========================> True
# (3, 4)
# b'nomask: 0.77'
# b'nomask: 0.67'
# b'nomask: 0.63'
# FPS: 13.07
# ===========================> True
# (3, 4)
# b'nomask: 0.78'
# b'nomask: 0.66'
# b'nomask: 0.64'
# FPS: 13.15
# ===========================> True
# (3, 4)
# b'nomask: 0.87'
# b'nomask: 0.71'
# b'nomask: 0.69'
# FPS: 13.15
# ===========================> True
# (3, 4)
# b'nomask: 0.88'
# b'nomask: 0.71'
# b'nomask: 0.68'
# FPS: 12.91
# ===========================> True
# (3, 4)
# b'nomask: 0.88'
# b'nomask: 0.71'
# b'nomask: 0.66'
# FPS: 13.11
# ===========================> True
# (3, 4)
# b'nomask: 0.88'
# b'nomask: 0.71'
# b'nomask: 0.66'
# FPS: 13.22
# ===========================> True
# (3, 4)
# b'nomask: 0.88'
# b'nomask: 0.71'
# b'nomask: 0.66'
# FPS: 13.12
# ===========================> True
# (3, 4)
# b'nomask: 0.88'
# b'nomask: 0.71'
# b'nomask: 0.66'
# FPS: 13.03
# ===========================> True
# (3, 4)
# b'nomask: 0.88'
# b'nomask: 0.70'
# b'nomask: 0.67'
# FPS: 13.00
# ===========================> True
# (3, 4)
# b'nomask: 0.88'
# b'nomask: 0.70'
# b'nomask: 0.67'
# FPS: 13.04
# ===========================> True
# (3, 4)
# b'nomask: 0.88'
# b'nomask: 0.69'
# b'nomask: 0.63'
# FPS: 13.12
# ===========================> True
# (3, 4)
# b'nomask: 0.88'
# b'nomask: 0.69'
# b'nomask: 0.64'
# FPS: 13.16
# ===========================> True
# (3, 4)
# b'nomask: 0.88'
# b'nomask: 0.69'
# b'nomask: 0.64'
# FPS: 13.31
# ===========================> True
# (3, 4)
# b'nomask: 0.88'
# b'nomask: 0.69'
# b'nomask: 0.64'
# FPS: 13.31
# ===========================> True
# (3, 4)
# b'nomask: 0.88'
# b'nomask: 0.69'
# b'nomask: 0.64'
# FPS: 13.26
# ===========================> True
# (3, 4)
# b'nomask: 0.85'
# b'nomask: 0.73'
# b'nomask: 0.70'
# FPS: 13.34
# ===========================> True
# (3, 4)
# b'nomask: 0.84'
# b'nomask: 0.74'
# b'nomask: 0.71'
# FPS: 12.97
# ===========================> True
# (3, 4)
# b'nomask: 0.84'
# b'nomask: 0.74'
# b'nomask: 0.71'
# FPS: 13.15
# ===========================> True
# (3, 4)
# b'nomask: 0.84'
# b'nomask: 0.74'
# b'nomask: 0.72'
# FPS: 13.09
# ===========================> True
# (3, 4)
# b'nomask: 0.84'
# b'nomask: 0.74'
# b'nomask: 0.72'
# FPS: 13.12
# ===========================> True
# (3, 4)
# b'nomask: 0.84'
# b'nomask: 0.74'
# b'nomask: 0.72'
# FPS: 13.21
# ===========================> True
# (3, 4)
# b'nomask: 0.85'
# b'nomask: 0.77'
# b'nomask: 0.72'
# FPS: 13.36
# ===========================> True
# (3, 4)
# b'nomask: 0.85'
# b'nomask: 0.79'
# b'nomask: 0.71'
# FPS: 13.26
# ===========================> True
# (3, 4)
# b'nomask: 0.84'
# b'nomask: 0.77'
# b'nomask: 0.69'
# FPS: 13.26
# ===========================> True
# (3, 4)
# b'nomask: 0.87'
# b'nomask: 0.76'
# b'nomask: 0.77'
# FPS: 13.26
# ===========================> True
# (2, 4)
# b'nomask: 0.86'
# b'nomask: 0.65'
# FPS: 13.47
# ===========================> True
# (2, 4)
# b'nomask: 0.84'
# b'nomask: 0.79'
# FPS: 13.54
# ===========================> True
# (2, 4)
# b'nomask: 0.87'
# b'nomask: 0.65'
# FPS: 13.40
# ===========================> True
# (3, 4)
# b'nomask: 0.87'
# b'nomask: 0.85'
# b'nomask: 0.81'
# FPS: 13.11
# ===========================> True
# (2, 4)
# b'nomask: 0.88'
# b'nomask: 0.77'
# FPS: 13.02
# ===========================> True
# (3, 4)
# b'nomask: 0.94'
# b'nomask: 0.77'
# b'nomask: 0.60'
# FPS: 13.06
# ===========================> True
# (3, 4)
# b'nomask: 0.89'
# b'nomask: 0.77'
# b'nomask: 0.70'
# FPS: 13.16
# ===========================> True
# (2, 4)
# b'nomask: 0.89'
# b'nomask: 0.61'
# FPS: 13.50
# ===========================> True
# (3, 4)
# b'nomask: 0.82'
# b'nomask: 0.74'
# b'nomask: 0.55'
# FPS: 13.49
# ===========================> True
# (2, 4)
# b'nomask: 0.93'
# b'nomask: 0.82'
# FPS: 13.54
# ===========================> True
# (3, 4)
# b'nomask: 0.88'
# b'nomask: 0.77'
# b'nomask: 0.54'
# FPS: 13.43
# ===========================> True
# (3, 4)
# b'nomask: 0.91'
# b'nomask: 0.84'
# b'nomask: 0.81'
# FPS: 13.20
# ===========================> True
# (3, 4)
# b'nomask: 0.93'
# b'nomask: 0.88'
# b'nomask: 0.87'
# FPS: 13.23
# ===========================> True
# (3, 4)
# b'nomask: 0.89'
# b'nomask: 0.87'
# b'nomask: 0.84'
# FPS: 12.93
# ===========================> True
# (3, 4)
# b'nomask: 0.92'
# b'nomask: 0.85'
# b'nomask: 0.79'
# FPS: 13.10
# ===========================> True
# (3, 4)
# b'nomask: 0.80'
# b'nomask: 0.80'
# b'nomask: 0.65'
# FPS: 12.84
# ===========================> True
# (3, 4)
# b'nomask: 0.84'
# b'nomask: 0.75'
# b'nomask: 0.71'
# FPS: 12.74
# ===========================> True
# (2, 4)
# b'nomask: 0.85'
# b'nomask: 0.81'
# FPS: 12.82
# ===========================> True
# (3, 4)
# b'nomask: 0.88'
# b'nomask: 0.88'
# b'nomask: 0.77'
# FPS: 12.92
# ===========================> True
# (3, 4)
# b'nomask: 0.84'
# b'nomask: 0.84'
# b'nomask: 0.81'
# FPS: 13.09
# ===========================> True
# (3, 4)
# b'nomask: 0.75'
# b'nomask: 0.73'
# b'nomask: 0.50'
# FPS: 13.26
# ===========================> True
# (3, 4)
# b'nomask: 0.94'
# b'nomask: 0.84'
# b'nomask: 0.75'
# FPS: 13.24
# ===========================> True
# (3, 4)
# b'nomask: 0.88'
# b'nomask: 0.83'
# b'nomask: 0.82'
# FPS: 13.18
# ===========================> True
# (2, 4)
# b'nomask: 0.89'
# b'nomask: 0.79'
# FPS: 13.40
# ===========================> True
# (3, 4)
# b'nomask: 0.93'
# b'nomask: 0.78'
# b'nomask: 0.63'
# FPS: 13.23
# ===========================> True
# (3, 4)
# b'nomask: 0.90'
# b'nomask: 0.77'
# b'nomask: 0.74'
# FPS: 13.19
# ===========================> True
# (2, 4)
# b'nomask: 0.88'
# b'nomask: 0.85'
# FPS: 13.34
# ===========================> True
# (4, 4)
# b'nomask: 0.92'
# b'nomask: 0.88'
# b'nomask: 0.84'
# b'nomask: 0.62'
# FPS: 13.09
# ===========================> True
# (3, 4)
# b'nomask: 0.86'
# b'nomask: 0.73'
# b'nomask: 0.66'
# FPS: 13.16
# ===========================> True
# (3, 4)
# b'nomask: 0.86'
# b'nomask: 0.81'
# b'nomask: 0.80'
# FPS: 12.88
# ===========================> True
# (2, 4)
# b'nomask: 0.78'
# b'nomask: 0.73'
# FPS: 13.06
# ===========================> True
# (3, 4)
# b'nomask: 0.89'
# b'nomask: 0.82'
# b'nomask: 0.79'
# FPS: 13.08
# ===========================> True
# (3, 4)
# b'nomask: 0.86'
# b'nomask: 0.85'
# b'nomask: 0.60'
# FPS: 13.22
# ===========================> True
# (3, 4)
# b'nomask: 0.85'
# ===========================> True
# FPS: 14.50
# ===========================> True
# FPS: 14.46
# ===========================> True
# FPS: 14.55
# ===========================> True
# FPS: 14.54
# ===========================> True
# FPS: 14.62
# ===========================> True
# FPS: 14.59
# ===========================> True
# FPS: 14.50
# ===========================> True
# FPS: 14.55
# ===========================> True
# FPS: 14.61
# ===========================> True
# (1, 4)
# b'mask: 0.73'
# FPS: 14.22
# ===========================> True
# (1, 4)
# b'mask: 0.58'
# FPS: 13.97
# ===========================> True
# (1, 4)
# b'mask: 0.76'
# FPS: 13.88
# ===========================> True
# (1, 4)
# b'nomask: 0.57'
# FPS: 13.85
# ===========================> True
# FPS: 14.26
# ===========================> True
# FPS: 14.40
# ===========================> True
# (0, 4)
# FPS: 14.20
# ===========================> True
# (1, 4)
# b'nomask: 0.58'
# FPS: 14.11
# ===========================> True
# FPS: 14.42
# ===========================> True
# FPS: 14.50
# ===========================> True
# FPS: 14.36
# ===========================> True
# FPS: 14.23
# ===========================> True
# (1, 4)
# b'mask: 0.58'
# FPS: 13.83
# ===========================> True
# (1, 4)
# b'mask: 0.76'
# FPS: 13.77
# ===========================> True
# (2, 4)
# b'mask: 0.69'
# b'nomask: 0.60'
# FPS: 13.67
# ===========================> True
# (2, 4)
# b'mask: 0.64'
# b'nomask: 0.81'
# FPS: 13.65
# ===========================> True
# (2, 4)
# b'mask: 0.58'
# b'nomask: 0.78'
# FPS: 13.55
# ===========================> True
# (2, 4)
# b'mask: 0.85'
# b'nomask: 0.69'
# FPS: 13.63
# ===========================> True
# (2, 4)
# b'mask: 0.84'
# b'nomask: 0.75'
# FPS: 13.65
# ===========================> True
# (2, 4)
# b'mask: 0.87'
# b'nomask: 0.69'
# FPS: 13.63
# ===========================> True
# (2, 4)
# b'mask: 0.81'
# b'nomask: 0.83'
# FPS: 13.60
# ===========================> True
# (2, 4)
# b'mask: 0.83'
# b'nomask: 0.69'
# FPS: 13.68
# ===========================> True
# (2, 4)
# b'mask: 0.86'
# b'nomask: 0.70'
# FPS: 13.63
# ===========================> True
# (2, 4)
# b'mask: 0.89'
# b'nomask: 0.79'
# FPS: 13.57
# ===========================> True
# (2, 4)
# b'mask: 0.83'
# b'nomask: 0.77'
# FPS: 13.48
# ===========================> True
# (2, 4)
# b'mask: 0.91'
# b'nomask: 0.69'
# FPS: 13.33
# ===========================> True
# (2, 4)
# b'mask: 0.89'
# b'nomask: 0.50'
# FPS: 13.38
# ===========================> True
# (2, 4)
# b'mask: 0.82'
# b'nomask: 0.64'
# FPS: 13.52
# ===========================> True
# (2, 4)
# b'mask: 0.70'
# b'nomask: 0.54'
# FPS: 13.73
# ===========================> True
# (2, 4)
# b'mask: 0.79'
# b'nomask: 0.61'
# FPS: 13.68
# ===========================> True
# (2, 4)
# b'mask: 0.65'
# b'nomask: 0.56'
# FPS: 13.65
# ===========================> True
# (2, 4)
# b'mask: 0.71'
# b'nomask: 0.62'
# FPS: 13.76
# ===========================> True
# (1, 4)
# b'mask: 0.71'
# FPS: 13.77
# ===========================> True
# (2, 4)
# b'mask: 0.69'
# b'nomask: 0.56'
# FPS: 13.23
# ===========================> True
# (2, 4)
# b'mask: 0.73'
# b'nomask: 0.62'
# FPS: 13.43
# ===========================> True
# (2, 4)
# b'mask: 0.65'
# b'nomask: 0.55'
# FPS: 13.55
# ===========================> True
# (2, 4)
# b'mask: 0.67'
# b'nomask: 0.65'
# FPS: 13.44
# ===========================> True
# (2, 4)
# b'mask: 0.66'
# b'nomask: 0.67'
# FPS: 13.36
# ===========================> True
# (2, 4)
# b'mask: 0.65'
# b'nomask: 0.71'
# FPS: 13.37
# ===========================> True
# (2, 4)
# b'mask: 0.64'
# b'nomask: 0.72'
# FPS: 13.63
# ===========================> True
# (2, 4)
# b'mask: 0.63'
# b'nomask: 0.60'
# FPS: 13.71
# ===========================> True
# (2, 4)
# b'mask: 0.64'
# b'nomask: 0.55'
# FPS: 13.70
# ===========================> True
# (2, 4)
# b'mask: 0.64'
# b'nomask: 0.54'
# FPS: 13.72
# ===========================> True
# (2, 4)
# b'mask: 0.65'
# b'nomask: 0.56'
# FPS: 13.59
# ===========================> True
# (1, 4)
# b'mask: 0.96'
# FPS: 13.72
# ===========================> True
# (1, 4)
# b'mask: 0.96'
# FPS: 13.89
# ===========================> True
# (1, 4)
# b'mask: 0.95'
# FPS: 13.84
# ===========================> True
# (1, 4)
# b'mask: 0.95'
# FPS: 13.64
# ===========================> True
# (1, 4)
# b'mask: 0.95'
# FPS: 13.79
# ===========================> True
# (1, 4)
# b'mask: 0.95'
# FPS: 13.81
# ===========================> True
# (1, 4)
# b'mask: 0.95'
# FPS: 13.84
# ===========================> True
# (1, 4)
# b'mask: 0.95'
# FPS: 13.82
# ===========================> True
# (1, 4)
# b'mask: 0.95'
# FPS: 13.62
# ===========================> True
# (1, 4)
# b'mask: 0.94'
# FPS: 13.61
# ===========================> True
# (1, 4)
# b'mask: 0.94'
# FPS: 13.71
# ===========================> True
# (1, 4)
# b'mask: 0.92'
# FPS: 13.86
# ===========================> True
# (1, 4)
# b'mask: 0.90'
# FPS: 13.81
# ===========================> True
# (1, 4)
# b'mask: 0.90'
# FPS: 13.92
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.78'
# FPS: 13.77
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.82'
# FPS: 13.51
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.87'
# FPS: 13.32
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.87'
# FPS: 13.54
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.91'
# FPS: 13.56
# ===========================> True
# (2, 4)
# b'mask: 0.91'
# b'nomask: 0.90'
# FPS: 13.57
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.89'
# FPS: 13.51
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.88'
# FPS: 13.21
# ===========================> True
# (2, 4)
# b'mask: 0.91'
# b'nomask: 0.90'
# FPS: 13.25
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.87'
# FPS: 13.34
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.84'
# FPS: 13.39
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.84'
# FPS: 13.54
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.84'
# FPS: 13.49
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.84'
# FPS: 13.42
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.84'
# FPS: 13.60
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.84'
# FPS: 13.67
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.85'
# FPS: 13.42
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.88'
# FPS: 13.39
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.88'
# FPS: 13.25
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.87'
# FPS: 13.45
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.88'
# FPS: 13.21
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.87'
# FPS: 13.29
# ===========================> True
# (2, 4)
# b'mask: 0.90'
# b'nomask: 0.91'
# FPS: 13.40
# ===========================> True
# (2, 4)
# b'mask: 0.91'
# b'nomask: 0.90'
# FPS: 13.66
# ===========================> True
# (2, 4)
# b'mask: 0.91'
# b'nomask: 0.90'
# FPS: 13.63
# ===========================> True
# (2, 4)
# b'mask: 0.91'
# b'nomask: 0.91'
# FPS: 13.59
# ===========================> True
# (2, 4)
# b'mask: 0.92'
# b'nomask: 0.90'
# FPS: 13.53
# ===========================> True
# (2, 4)
# b'mask: 0.92'
# b'nomask: 0.90'
# FPS: 13.44
# ===========================> True
# (2, 4)
# b'mask: 0.91'
# b'nomask: 0.93'
# FPS: 13.41
# ===========================> True
# (2, 4)
# b'mask: 0.91'
# b'nomask: 0.94'
# FPS: 13.44
# ===========================> True
# (2, 4)
# b'mask: 0.91'
# b'nomask: 0.94'
# FPS: 13.49
# ===========================> True
# (2, 4)
# b'mask: 0.91'
# b'nomask: 0.94'
# FPS: 13.51
# ===========================> True
# (2, 4)
# b'mask: 0.91'
# b'nomask: 0.94'
# FPS: 13.39
# ===========================> True
# (2, 4)
# b'mask: 0.91'
# b'nomask: 0.94'
# FPS: 13.44
# ===========================> True
# (3, 4)
# b'mask: 0.90'
# b'nomask: 0.96'
# b'nomask: 0.55'
# FPS: 13.24
# ===========================> True
# (3, 4)
# b'mask: 0.90'
# b'nomask: 0.96'
# b'nomask: 0.55'
# FPS: 13.33
# ===========================> True
# (3, 4)
# b'mask: 0.90'
# b'nomask: 0.96'
# b'nomask: 0.55'
# FPS: 13.29
# ===========================> True
# (3, 4)
# b'mask: 0.90'
# b'nomask: 0.96'
# b'nomask: 0.55'
# FPS: 13.42
# ===========================> True
# (3, 4)
# b'mask: 0.90'
# b'nomask: 0.96'
# b'nomask: 0.55'
# FPS: 13.46
# ===========================> True
# (3, 4)
# b'mask: 0.90'
# b'nomask: 0.96'
# b'nomask: 0.54'
# FPS: 13.49
# ===========================> True
# (3, 4)
# b'mask: 0.90'
# b'nomask: 0.96'
# b'nomask: 0.54'
# FPS: 13.30
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.96'
# b'nomask: 0.53'
# FPS: 13.26
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.96'
# b'nomask: 0.53'
# FPS: 13.29
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.96'
# b'nomask: 0.53'
# FPS: 13.36
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.96'
# b'nomask: 0.53'
# FPS: 13.13
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.96'
# b'nomask: 0.53'
# FPS: 13.23
# ===========================> True
# (3, 4)
# b'mask: 0.90'
# b'nomask: 0.97'
# b'nomask: 0.56'
# FPS: 13.25
# ===========================> True
# (3, 4)
# b'mask: 0.90'
# b'nomask: 0.97'
# b'nomask: 0.55'
# FPS: 13.31
# ===========================> True
# (3, 4)
# b'mask: 0.90'
# b'nomask: 0.97'
# b'nomask: 0.54'
# FPS: 13.37
# ===========================> True
# (3, 4)
# b'mask: 0.90'
# b'nomask: 0.97'
# b'nomask: 0.54'
# FPS: 13.40
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.54'
# FPS: 13.25
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.53'
# FPS: 13.32
# ===========================> True
# (3, 4)
# b'mask: 0.90'
# b'nomask: 0.97'
# b'nomask: 0.63'
# FPS: 13.48
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.60'
# FPS: 13.53
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.60'
# FPS: 13.46
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.59'
# FPS: 13.51
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.59'
# FPS: 13.23
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.59'
# FPS: 13.34
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.61'
# FPS: 13.29
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.58'
# FPS: 13.30
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.57'
# FPS: 13.19
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.56'
# FPS: 13.33
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.57'
# FPS: 13.33
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.57'
# FPS: 13.33
# ===========================> True
# (3, 4)
# b'mask: 0.92'
# b'nomask: 0.97'
# b'nomask: 0.51'
# FPS: 13.43
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.57'
# FPS: 13.48
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.57'
# FPS: 13.44
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.58'
# FPS: 13.37
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.58'
# FPS: 13.08
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.58'
# FPS: 13.29
# ===========================> True
# (3, 4)
# b'mask: 0.92'
# b'nomask: 0.97'
# b'nomask: 0.64'
# FPS: 13.27
# ===========================> True
# (3, 4)
# b'mask: 0.91'
# b'nomask: 0.97'
# b'nomask: 0.60'
# FPS: 13.24
# ===========================> True
# FPS: 14.19
# ===========================> True
# FPS: 14.49
# ===========================> True
# FPS: 14.61
# ===========================> True
# FPS: 14.63
# ===========================> True
# FPS: 14.63
# ===========================> True
# FPS: 14.75
# ===========================> True
# FPS: 14.72
# ===========================> True
# FPS: 14.75
# ===========================> True
# FPS: 14.86
# ===========================> True
# FPS: 14.69
# ===========================> True
# FPS: 14.78
# ===========================> True
# FPS: 14.85
# ===========================> True
# FPS: 14.70
# ===========================> True
# FPS: 14.84
# ===========================> True
# FPS: 14.72
# ===========================> True
# FPS: 14.59
# ===========================> True
# FPS: 14.54
# ===========================> True
# FPS: 14.24
# ===========================> True
# FPS: 14.37
# ===========================> True
# FPS: 14.52
# ===========================> True
# FPS: 14.63
# ===========================> True
# FPS: 14.62
# ===========================> True
# FPS: 14.71
# ===========================> True
# FPS: 14.69
# ===========================> True
# FPS: 14.69
# ===========================> True
# FPS: 14.71
# ===========================> True
# FPS: 14.33
# ===========================> True
# FPS: 14.48
# ===========================> True
# FPS: 14.45
# ===========================> True
# (1, 4)
# b'mask: 0.77'
# FPS: 14.15
# ===========================> True
# (1, 4)
# b'mask: 0.78'
# FPS: 13.91
# ===========================> True
# (1, 4)
# b'mask: 0.77'
# FPS: 13.86
# ===========================> True
# (1, 4)
# b'mask: 0.76'
# FPS: 13.83
# ===========================> True
# (1, 4)
# b'mask: 0.75'
# FPS: 13.73
# ===========================> True
# (1, 4)
# b'mask: 0.73'
# FPS: 13.90
# ===========================> True
# (1, 4)
# b'mask: 0.75'
# FPS: 13.71
# ===========================> True
# (1, 4)
# b'mask: 0.77'
# FPS: 13.54
